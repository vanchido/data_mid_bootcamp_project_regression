# %% [markdown]
# # Explore the data

# %% [markdown]
# ### Data Import

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

from scipy import stats

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('regression_data.xls')

cities = pd.read_excel('geo-data.xls')

# We add another dataset here in order to change 'zipcode' to 'city' afterwards

data.shape
# Out:
# (21597, 21)

# %%
data
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 3      2487200875 2014-12-09         4       3.00         1960      5000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 0         1.0           0     0          3  ...        1180              0
# 1         2.0           0     0          3  ...        2170            400
# 2         1.0           0     0          3  ...         770              0
# 3         1.0           0     0          5  ...        1050            910
# 4         1.0           0     0          3  ...        1680              0
# ...       ...         ...   ...        ...  ...         ...            ...
# 21592     3.0           0     0          3  ...        1530              0
# 21593     2.0           0     0          3  ...        2310              0
# 21594     2.0           0     0          3  ...        1020              0
# 21595     2.0           0     0          3  ...        1600              0
# 21596     2.0           0     0          3  ...        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21592      2009             0    98103  47.6993 -122.346           1530
# 21593      2014             0    98146  47.5107 -122.362           1830
# 21594      2009             0    98144  47.5944 -122.299           1020
# 21595      2004             0    98027  47.5345 -122.069           1410
# 21596      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15   price
# 0            5650  221900
# 1            7639  538000
# 2            8062  180000
# 3            5000  604000
# 4            7503  510000
# ...           ...     ...
# 21592        1509  360000
# 21593        7200  400000
# 21594        2007  402101
# 21595        1287  400000
# 21596        1357  325000
#
# [21597 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %% [markdown]
# **This dataset has:**
# <br />**date:** date which the property was sold
# <br />**bedrooms/bathrooms:** nb of bedrooms/bathrooms in the property
# <br />**sqft_living:** living room area
# <br />**sqft_lot:** lotsize area
# <br />**floors:** which floor the property is in
# <br />**waterfront:** the house which has a view to a waterfront
# <br />**view:** *(it is not said how this variable is constructed)*
# <br />**condition:** How good the condition is (Overall). 1 indicates worn-out property and 5 excellent.
# <br />**grade:** Overall grade given to the housing unit, based on the King County grading system. 1 poor, 13 excellent.
# <br />**sqft_above:** square footage of house apart from the basement
# <br />**sqft_basement:** square footage in the basement
# <br />**yr_built:** the year the property was built
# <br />**yr_renovated:** the year the property was renovated
# <br />**zipcode:** where the property is located
# <br />**lat/long:** latitude/longtitude of the property
# <br />**sqft_living15:** Living room area in 2015(implies-- some renovations) This might or might not have affected the lotSize area
# <br />**sqft_lot15:** lotSize area in 2015(implies-- some renovations)
# <br />**price:** *our target variable*

# %% [markdown]
# At first glance, I would choose to focus on the below variables for my model:
# <br />**sqft_living:** *(usually the bigger the living area, the more expensive the property)*
# <br />**sqft_lot:** *(usually the bigger the lot, the more expensive the property)*
# <br />**floors:** *(usually the middle or highest property are more expensive than those on the basement)*
# <br />**waterfront:** *(usually if the property is waterfront, it is more expensive)*
# <br />**condition:** *(the higher the more expensive)*
# <br />**grade:** *(the higher the more expensive)*
# <br />**zipcode:** *(this should be transform to city and then grouped in bins by prices, so at least we have an idea which city is more expensive than the other - a categorical variable which called "location" would help the model)*
# <br />**lat/long:** *(latitude/longtitude are also variables which would help locating the property, and help the model predicts more accurately)*
# <br />**sqft_living15/sqft_lot15:** *(I would expect the more the renovations, the less expensive the property)*

# %% [markdown]
# #### Introducing a new variable to the dataset

# %%
# As I said above, I would like to tranform the zipcode into city in order to create bin of city by prices

# Convert dtype of 'zipcode' in 'cities' to the same dtype of 'zipcode' in 'data'
cities['zipcode'] = cities['zipcode'].astype(int)

# Merge 'data' and 'cities' to have column 'city' in our dataset
data = data.merge(cities[['zipcode','city']], how='left',on='zipcode')
data
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 3      2487200875 2014-12-09         4       3.00         1960      5000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 0         1.0           0     0          3  ...              0      1955
# 1         2.0           0     0          3  ...            400      1951
# 2         1.0           0     0          3  ...              0      1933
# 3         1.0           0     0          5  ...            910      1965
# 4         1.0           0     0          3  ...              0      1987
# ...       ...         ...   ...        ...  ...            ...       ...
# 21592     3.0           0     0          3  ...              0      2009
# 21593     2.0           0     0          3  ...              0      2014
# 21594     2.0           0     0          3  ...              0      2009
# 21595     2.0           0     0          3  ...              0      2004
# 21596     2.0           0     0          3  ...              0      2008
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 0                 0    98178  47.5112 -122.257           1340        5650
# 1              1991    98125  47.7210 -122.319           1690        7639
# 2                 0    98028  47.7379 -122.233           2720        8062
# 3                 0    98136  47.5208 -122.393           1360        5000
# 4                 0    98074  47.6168 -122.045           1800        7503
# ...             ...      ...      ...      ...            ...         ...
# 21592             0    98103  47.6993 -122.346           1530        1509
# 21593             0    98146  47.5107 -122.362           1830        7200
# 21594             0    98144  47.5944 -122.299           1020        2007
# 21595             0    98027  47.5345 -122.069           1410        1287
# 21596             0    98144  47.5941 -122.299           1020        1357
#
#         price             city
# 0      221900          Tukwila
# 1      538000          Seattle
# 2      180000          Kenmore
# 3      604000          Seattle
# 4      510000  Sammamish North
# ...       ...              ...
# 21592  360000          Seattle
# 21593  400000           Burien
# 21594  402101          Seattle
# 21595  400000         Issaquah
# 21596  325000          Seattle
#
# [21597 rows x 22 columns]

# %%
# Adding column 'avg_price_city' to reflect the average house price of that city

sr_location = data.groupby('city')['price'].mean()
data = data.join(sr_location.rename('avg_price_city'),on='city')
data.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price', 'city', 'avg_price_city'],
#       dtype='object')

# %%
# Check data types
# Here we see 'bathrooms' shouldn't be float64 but int64

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 0 to 21596
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21597 non-null  int64
#  1   date            21597 non-null  datetime64[ns]
#  2   bedrooms        21597 non-null  int64
#  3   bathrooms       21597 non-null  float64
#  4   sqft_living     21597 non-null  int64
#  5   sqft_lot        21597 non-null  int64
#  6   floors          21597 non-null  float64
#  7   waterfront      21597 non-null  int64
#  8   view            21597 non-null  int64
#  9   condition       21597 non-null  int64
#  10  grade           21597 non-null  int64
#  11  sqft_above      21597 non-null  int64
#  12  sqft_basement   21597 non-null  int64
#  13  yr_built        21597 non-null  int64
#  14  yr_renovated    21597 non-null  int64
#  15  zipcode         21597 non-null  int64
#  16  lat             21597 non-null  float64
#  17  long            21597 non-null  float64
#  18  sqft_living15   21597 non-null  int64
#  19  sqft_lot15      21597 non-null  int64
#  20  price           21597 non-null  int64
#  21  city            21597 non-null  object
#  22  avg_price_city  21597 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(16), object(1)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Data Cleaning

# %%
pd.set_option('display.max_rows', 40)
pd.set_option('display.min_rows', 20)
pd.set_option('display.expand_frame_repr', True)

# %%
# Round nb of bathrooms to unitary values

data['bathrooms'] = data['bathrooms'].apply(lambda x: int(round(x,0)))
data['bathrooms']
# Out:
# 0        1
# 1        2
# 2        1
# 3        3
# 4        2
# 5        4
# 6        2
# 7        2
# 8        1
# 9        2
#         ..
# 21587    2
# 21588    2
# 21589    2
# 21590    4
# 21591    2
# 21592    2
# 21593    2
# 21594    1
# 21595    2
# 21596    1
# Name: bathrooms, Length: 21597, dtype: int64

# %%
# Remove unnecessary columns & drop the 'zipcode'(numerical) as now we have the 'city'(categorical) instead

data = data.drop(columns=['date','zipcode','yr_renovated','yr_built'], axis=1)
data.dtypes
# Out:
# id                  int64
# bedrooms            int64
# bathrooms           int64
# sqft_living         int64
# sqft_lot            int64
# floors            float64
# waterfront          int64
# view                int64
# condition           int64
# grade               int64
# sqft_above          int64
# sqft_basement       int64
# lat               float64
# long              float64
# sqft_living15       int64
# sqft_lot15          int64
# price               int64
# city               object
# avg_price_city    float64
# dtype: object

# %%
data = data.set_index('id')

# %% [markdown]
# ### EDA

# %%
var = 'sqft_living'
relation = pd.concat([data['price'], data[var]], axis=1)
relation.plot.scatter(x='price', y=var)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %% [markdown]
# Here we do see clear positive correlation between the living area and the price

# %%
var = 'sqft_above'
relation = pd.concat([data['price'], data[var]], axis=1)
relation.plot.scatter(x='price', y=var)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_above'>

# %% [markdown]
# And same remark for the above basement area

# %%
var = 'grade'
relation = pd.concat([data['price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y='price', data=relation)

# %%
var = 'view'
relation = pd.concat([data['price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y='price', data=relation)

# %% [markdown]
# Although there are some outliers, we do have a relationship between the price and the view (higher the view, higher the price)

# %%
var = 'condition'
relation = pd.concat([data['price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y='price', data=relation)

# %% [markdown]
# The same can be said for 'condition'

# %%
var = 'lat'
relation = pd.concat([data['price'], data[var]], axis=1)
relation.plot.scatter(x='price', y=var)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %% [markdown]
# Prices are the highest for latitude 47.65 ...

# %%
var = 'long'
relation = pd.concat([data['price'], data[var]], axis=1)
relation.plot.scatter(x='price', y=var)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %% [markdown]
# ... and for longtitude 122.22

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='long',y='lat',data=data,size='price',hue='price',palette='viridis',sizes=(20,200))
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %% [markdown]
# Here we see that houses that are around the water in the middle is the most expensive * obvious *

# %%
data.describe().apply(lambda x: round(x,2))
# Out:
#        bedrooms  bathrooms  sqft_living    sqft_lot    floors  waterfront  \
# count  21597.00   21597.00     21597.00    21597.00  21597.00    21597.00
# mean       3.37       2.06      2080.32    15099.41      1.49        0.01
# std        0.93       0.75       918.11    41412.64      0.54        0.09
# min        1.00       0.00       370.00      520.00      1.00        0.00
# 25%        3.00       2.00      1430.00     5040.00      1.00        0.00
# 50%        3.00       2.00      1910.00     7618.00      1.50        0.00
# 75%        4.00       2.00      2550.00    10685.00      2.00        0.00
# max       33.00       8.00     13540.00  1651359.00      3.50        1.00
#
#            view  condition     grade  sqft_above  sqft_basement       lat  \
# count  21597.00   21597.00  21597.00    21597.00       21597.00  21597.00
# mean       0.23       3.41      7.66     1788.60         291.73     47.56
# std        0.77       0.65      1.17      827.76         442.67      0.14
# min        0.00       1.00      3.00      370.00           0.00     47.16
# 25%        0.00       3.00      7.00     1190.00           0.00     47.47
# 50%        0.00       3.00      7.00     1560.00           0.00     47.57
# 75%        0.00       4.00      8.00     2210.00         560.00     47.68
# max        4.00       5.00     13.00     9410.00        4820.00     47.78
#
#            long  sqft_living15  sqft_lot15       price  avg_price_city
# count  21597.00       21597.00    21597.00    21597.00        21597.00
# mean    -122.21        1986.62    12758.28   540296.57       540296.57
# std        0.14         685.23    27274.44   367368.14       208060.04
# min     -122.52         399.00      651.00    78000.00       234284.04
# 25%     -122.33        1490.00     5100.00   322000.00       403468.46
# 50%     -122.23        1840.00     7620.00   450000.00       594306.55
# 75%     -122.12        2360.00    10083.00   645000.00       612642.74
# max     -121.32        6210.00   871200.00  7700000.00      2161300.00

# %%
#Use seaborn library to construct distribution plots for the numerical variables
for column in data.select_dtypes(np.number):
    sns.distplot(data[column])
    plt.show()

# %%
data.corr().apply(lambda x: round(x,3))
# Out:
#                 bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# bedrooms           1.000      0.488        0.578     0.032   0.178
# bathrooms          0.488      1.000        0.703     0.091   0.368
# sqft_living        0.578      0.703        1.000     0.173   0.354
# sqft_lot           0.032      0.091        0.173     1.000  -0.005
# floors             0.178      0.368        0.354    -0.005   1.000
# waterfront        -0.007      0.065        0.104     0.022   0.024
# view               0.080      0.203        0.285     0.075   0.029
# condition          0.026     -0.068       -0.059    -0.009  -0.264
# grade              0.357      0.592        0.763     0.115   0.459
# sqft_above         0.479      0.600        0.876     0.184   0.524
# sqft_basement      0.303      0.335        0.435     0.015  -0.246
# lat               -0.010      0.049        0.052    -0.086   0.049
# long               0.132      0.151        0.241     0.230   0.126
# sqft_living15      0.393      0.499        0.756     0.145   0.280
# sqft_lot15         0.031      0.088        0.184     0.718  -0.011
# price              0.309      0.520        0.702     0.090   0.257
# avg_price_city     0.105      0.194        0.250    -0.036   0.077
#
#                 waterfront   view  condition  grade  sqft_above  \
# bedrooms            -0.007  0.080      0.026  0.357       0.479
# bathrooms            0.065  0.203     -0.068  0.592       0.600
# sqft_living          0.104  0.285     -0.059  0.763       0.876
# sqft_lot             0.022  0.075     -0.009  0.115       0.184
# floors               0.024  0.029     -0.264  0.459       0.524
# waterfront           1.000  0.402      0.017  0.083       0.072
# view                 0.402  1.000      0.046  0.252       0.168
# condition            0.017  0.046      1.000 -0.147      -0.159
# grade                0.083  0.252     -0.147  1.000       0.756
# sqft_above           0.072  0.168     -0.159  0.756       1.000
# sqft_basement        0.081  0.277      0.174  0.168      -0.052
# lat                 -0.014  0.006     -0.015  0.114      -0.001
# long                -0.042 -0.078     -0.106  0.200       0.345
# sqft_living15        0.087  0.281     -0.093  0.714       0.732
# sqft_lot15           0.031  0.073     -0.003  0.121       0.195
# price                0.266  0.397      0.036  0.668       0.605
# avg_price_city       0.022  0.084      0.039  0.309       0.196
#
#                 sqft_basement    lat   long  sqft_living15  sqft_lot15  price  \
# bedrooms                0.303 -0.010  0.132          0.393       0.031  0.309
# bathrooms               0.335  0.049  0.151          0.499       0.088  0.520
# sqft_living             0.435  0.052  0.241          0.756       0.184  0.702
# sqft_lot                0.015 -0.086  0.230          0.145       0.718  0.090
# floors                 -0.246  0.049  0.126          0.280      -0.011  0.257
# waterfront              0.081 -0.014 -0.042          0.087       0.031  0.266
# view                    0.277  0.006 -0.078          0.281       0.073  0.397
# condition               0.174 -0.015 -0.106         -0.093      -0.003  0.036
# grade                   0.168  0.114  0.200          0.714       0.121  0.668
# sqft_above             -0.052 -0.001  0.345          0.732       0.195  0.605
# sqft_basement           1.000  0.110 -0.145          0.200       0.018  0.324
# lat                     0.110  1.000 -0.135          0.049      -0.086  0.307
# long                   -0.145 -0.135  1.000          0.336       0.256  0.022
# sqft_living15           0.200  0.049  0.336          1.000       0.184  0.585
# sqft_lot15              0.018 -0.086  0.256          0.184       1.000  0.083
# price                   0.324  0.307  0.022          0.585       0.083  1.000
# avg_price_city          0.152  0.524  0.034          0.282      -0.028  0.566
#
#                 avg_price_city
# bedrooms                 0.105
# bathrooms                0.194
# sqft_living              0.250
# sqft_lot                -0.036
# floors                   0.077
# waterfront               0.022
# view                     0.084
# condition                0.039
# grade                    0.309
# sqft_above               0.196
# sqft_basement            0.152
# lat                      0.524
# long                     0.034
# sqft_living15            0.282
# sqft_lot15              -0.028
# price                    0.566
# avg_price_city           1.000

# %%
corr_matrix=data.corr(method='pearson')
fig, ax = plt.subplots(figsize=(15, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
data.corr()['price'].sort_values(ascending=False)
# Out:
# price             1.000000
# sqft_living       0.701917
# grade             0.667951
# sqft_above        0.605368
# sqft_living15     0.585241
# avg_price_city    0.566353
# bathrooms         0.519628
# view              0.397370
# sqft_basement     0.323799
# bedrooms          0.308787
# lat               0.306692
# waterfront        0.266398
# floors            0.256804
# sqft_lot          0.089876
# sqft_lot15        0.082845
# condition         0.036056
# long              0.022036
# Name: price, dtype: float64

# %% [markdown]
# ### Feature Engineering

# %%
data1 = data.copy()

# %% [markdown]
# #### Train - test split

# %%
X = data1.drop(['price'], axis=1)
y = data1['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train_num = X_train.select_dtypes(np.number)
X_test_num = X_test.select_dtypes(np.number)

# %% [markdown]
# #### Standard Scaler

# %%
import pickle

transformer = StandardScaler()
transformer.fit(X_train_num)

# saving in a pickle
with open('std_transformer.pickle', 'wb') as file:
    pickle.dump(transformer, file)
    
# loading from a pickle  
with open('std_transformer.pickle', 'rb') as file:
    loaded_transformer = pickle.load(file)

X_train_ = loaded_transformer.transform(X_train_num)
X_test_ = loaded_transformer.transform(X_test_num)

# if you need to un-scale afterwards, speacially if you scaled target variable:
unscaled_X_train = loaded_transformer.inverse_transform(X_train_)

# it makes sense to scale the target variable as well
unscaled_X_train[0][0]
# Out:
# 1.3862943611198906

# %% [markdown]
# #### Dummifying

# %%
data1['waterfront'] = data1['waterfront'].apply(lambda x: 'inland' if x == 0 else 'nearwater')
data1.waterfront
# Out:
# id
# 7129300520    inland
# 6414100192    inland
# 5631500400    inland
# 2487200875    inland
# 1954400510    inland
# 7237550310    inland
# 1321400060    inland
# 2008000270    inland
# 2414600126    inland
# 3793500160    inland
#                ...
# 7852140040    inland
# 9834201367    inland
# 3448900210    inland
# 7936000429    inland
# 2997800021    inland
# 263000018     inland
# 6600060120    inland
# 1523300141    inland
# 291310100     inland
# 1523300157    inland
# Name: waterfront, Length: 21597, dtype: object

# %%
data1 = data1.join(pd.get_dummies(data1.waterfront)).drop(['waterfront'],axis=1)
data1
# Out:
#             bedrooms  bathrooms  sqft_living   sqft_lot  floors  view  \
# id
# 1000102     1.791759          3     7.783224   9.145588     2.0   0.0
# 1000102     1.791759          3     7.783224   9.145588     2.0   0.0
# 1000102     1.791759          3     7.783224   9.145588     2.0   0.0
# 1000102     1.791759          3     7.783224   9.145588     2.0   0.0
# 1200019     1.386294          2     7.630461  10.167235     1.0   0.0
# 1200021     1.098612          1     7.286192  10.668955     1.0   0.0
# 2800031     1.098612          1     7.265430   8.935772     1.5   0.0
# 3600057     1.386294          2     7.408531   8.161660     1.0   0.0
# 3600072     1.386294          3     7.705262   8.577347     1.0   0.0
# 3800008     1.609438          2     7.595890   9.809177     1.0   0.0
# ...              ...        ...          ...        ...     ...   ...
# 9839300875  1.098612          1     7.438384   8.389360     1.5   0.0
# 9839301055  1.098612          2     7.306531   8.389360     1.5   0.0
# 9839301060  1.098612          2     7.461640   8.389360     1.5   0.0
# 9839301165  0.693147          1     7.358831   8.389360     1.5   0.0
# 9842300036  1.098612          1     7.177782   8.333991     1.0   0.0
# 9842300095  1.609438          2     7.377759   8.335192     1.5   0.0
# 9842300485  0.693147          1     6.946976   8.905444     1.0   0.0
# 9842300540  1.098612          1     7.003065   8.325548     1.0   0.0
# 9895000040  0.693147          2     7.251345   6.912743     1.5   0.0
# 9900000190  1.098612          1     7.185387   8.999619     1.0   0.0
#
#             condition  grade  sqft_above  sqft_basement      lat     long  \
# id
# 1000102             3      7    7.783224       0.000000  47.3262 -122.214
# 1000102             3      7    7.783224       0.000000  47.3262 -122.214
# 1000102             3      7    7.783224       0.000000  47.3262 -122.214
# 1000102             3      7    7.783224       0.000000  47.3262 -122.214
# 1200019             4      8    7.056175       6.802395  47.4444 -122.351
# 1200021             3      7    7.286192       0.000000  47.4434 -122.347
# 2800031             4      6    6.917706       6.040255  47.4783 -122.265
# 3600057             3      7    6.633318       6.791221  47.5803 -122.294
# 3600072             5      7    7.064759       6.956545  47.5801 -122.294
# 3800008             3      7    7.595890       0.000000  47.4938 -122.262
# ...               ...    ...         ...            ...      ...      ...
# 9839300875          4      8    7.438384       0.000000  47.6120 -122.292
# 9839301055          4      7    7.306531       0.000000  47.6113 -122.292
# 9839301060          3      8    7.461640       0.000000  47.6115 -122.292
# 9839301165          4      8    7.358831       0.000000  47.6112 -122.293
# 9842300036          4      7    7.177782       0.000000  47.5301 -122.381
# 9842300095          3      7    7.377759       0.000000  47.5297 -122.381
# 9842300485          5      7    6.733402       5.298317  47.5285 -122.378
# 9842300540          4      7    6.579251       5.940171  47.5296 -122.379
# 9895000040          3      9    6.802395       6.234411  47.5446 -122.018
# 9900000190          3      6    6.779922       6.086775  47.4697 -122.351
#
#             sqft_living15  sqft_lot15   price           city  avg_price_city  \
# id
# 1000102          7.630461    8.897819  280000         Auburn   234284.035176
# 1000102          7.630461    8.897819  280000         Auburn   234284.035176
# 1000102          7.630461    8.897819  300000         Auburn   234284.035176
# 1000102          7.630461    8.897819  300000         Auburn   234284.035176
# 1200019          7.859413    9.993831  647500  Normandy park   431439.475884
# 1200021          7.718685    9.904637  400000  Normandy park   431439.475884
# 2800031          7.162397    9.241839  235000        Tukwila   294841.422040
# 3600057          7.299797    8.161660  402500        Seattle   594306.550110
# 3600072          7.339538    8.342840  680000        Seattle   594306.550110
# 3800008          7.528332    9.066239  178000        Tukwila   294841.422040
# ...                   ...         ...     ...            ...             ...
# 9839300875       7.383989    8.338067  800000        Seattle   594306.550110
# 9839301055       7.352441    8.389360  670000        Seattle   594306.550110
# 9839301060       7.461640    8.389360  650500        Seattle   594306.550110
# 9839301165       7.522941    8.389360  998500        Seattle   594306.550110
# 9842300036       7.021084    8.334712  415885        Seattle   594306.550110
# 9842300095       7.081709    8.335192  365000        Seattle   594306.550110
# 9842300485       7.565275    8.546752  380000        Seattle   594306.550110
# 9842300540       7.319865    8.420242  339000        Seattle   594306.550110
# 9895000040       7.272398    7.080026  399900       Issaquah   617053.966019
# 9900000190       6.907755    8.999619  268950  Normandy park   431439.475884
#
#             inland  nearwater
# id
# 1000102          1          0
# 1000102          1          0
# 1000102          1          0
# 1000102          1          0
# 1200019          1          0
# 1200021          1          0
# 2800031          1          0
# 3600057          1          0
# 3600072          1          0
# 3800008          1          0
# ...            ...        ...
# 9839300875       1          0
# 9839301055       1          0
# 9839301060       1          0
# 9839301165       1          0
# 9842300036       1          0
# 9842300095       1          0
# 9842300485       1          0
# 9842300540       1          0
# 9895000040       1          0
# 9900000190       1          0
#
# [21953 rows x 19 columns]

# %%
corr_matrix=data1.corr(method='pearson')
fig, ax = plt.subplots(figsize=(15, 8))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %% [markdown]
# ### Training the model

# %% [markdown]
# #### Linear Regression

# %%
model = LinearRegression()

# %%
model.fit(X_train_num, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test_num, y_test)
# Out:
# 0.6980512647524637

# %%
predictions = model.predict(X_test_num)

# %%
r2_score(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False)
# Out:
# (0.6980512647524637, 117990.26605180357, 214449.88408482357)

# %% [markdown]
# Check and remove some features to test

# %%
model.coef_
# Out:
# array([-7.46243097e+04,  4.66905463e+04, -8.49931018e+04,  3.77348583e+04,
#        -1.75282674e+04,  5.65344255e+05,  1.86104177e+05,  4.04040251e+04,
#         8.46122183e+04,  3.20192134e+05,  1.70099137e+04,  1.61730877e+05,
#        -2.90059426e+05,  2.48568388e+04, -2.81735369e+04,  6.45976236e-01])

# %%
model.feature_names_in_
# Out:
# array(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'lat', 'long', 'sqft_living15', 'sqft_lot15',
#        'avg_price_city'], dtype=object)

# %%
cols_to_remove = pd.DataFrame([abs(i) for i in model.coef_], index=model.feature_names_in_, columns=['coef']).sort_values('coef', ascending=False).tail(2).index
cols_to_remove
# Out:
# Index(['sqft_basement', 'avg_price_city'], dtype='object')

# %% [markdown]
# Remove the above features

# %%
X = data.drop(cols_to_remove, axis=1).drop('price', axis=1)
y = data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

X_train_num = X_train.select_dtypes(np.number)
X_test_num = X_test.select_dtypes(np.number)

model = LinearRegression()
model.fit(X_train_num, y_train)

# this R2 is very similar to the result of the previous model in which we used these 40 extra columns
model.score(X_test_num, y_test)
# Out:
# 0.6690027936063772

# %% [markdown]
# Conclusion: The model performs worse than before. I shouldn't remove them

# %% [markdown]
# #### KNN - K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=10)
knn.fit(X_train_num, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=10)

# %%
knn.score(X_test_num, y_test)
# Out:
# 0.48972958732154204

# %% [markdown]
# I actually tried all numbers here and turned out number of neighbors = 10 gives the best score

# %% [markdown]
# #### Random Forest Regression

# %%
forest = RandomForestRegressor()

# %%
forest.fit(X_train_num, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_num, y_test)
# Out:
# 0.8756481815895993

# %%
predictions = forest.predict(X_test_num)

# %%
r2_score(y_test, predictions), mean_absolute_error(y_test, predictions), mean_squared_error(y_test, predictions, squared=False)
# Out:
# (0.8756481815895993, 69565.24276615777, 127250.27001440836)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# After running 3 models: Linear Regression, KNN and Random Forest Regressor, it's clear that the last model is the most robust, and the KNN model performs not that well.
